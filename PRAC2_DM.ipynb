# %%
import pandas as pd
import numpy as np

length = pd.read_csv('/content/global_wolves.csv')
length
# Out:
#                                            Victims             Date  \
# 0                           Martino Raineri, male         17-Jan-22
# 1                          Stanley Russ, 72, male         29-May-20
# 2                 Vlastimil Vejrosta and his wife   April 30, 2020
# 3                      Timur Makhametov, 23, male         30-Dec-19
# 4                            Unknown, adult, male         12-Dec-19
# ..                                             ...              ...
# 457                          Anna Maria, 9, female      March, 1705
# 458                                      16 people             1704
# 459             Unknown girl, age unknown, female              1650
# 460                                 40+ Parisians              1439
# 461  Radegund von Wellenburg, age unknown, female    July 18, 1340
#
#     Type of attack                                            Address  \
# 0       Unprovoked  Between Malga Seconda Posta and Forte Cherle, ...
# ...

# %%
length.count()
# Out:
# Victims           461
# Date              448
# Type of attack    432
# Address           454
# Notes             386
# Integer           428
# dtype: int64

# %%
length_missing = length.isna()
length_missing.head()
# Out:
#    Victims   Date  Type of attack  Address  Notes  Integer
# 0    False  False           False    False  False    False
# 1    False  False           False    False  False     True
# 2    False  False           False    False  False    False
# 3    False  False           False    False  False    False
# 4    False  False           False    False  False    False

# %%
length_missing.dtypes
# Out:
# Victims           bool
# Date              bool
# Type of attack    bool
# Address           bool
# Notes             bool
# Integer           bool
# dtype: object

# %%
# sum
length_num_missing = length_missing.sum()
B=length_num_missing
A=len(length)
print(B/A)
# Out:
# Victims           0.002165
# Date              0.030303
# Type of attack    0.064935
# Address           0.017316
# Notes             0.164502
# Integer           0.073593
# dtype: float64

# %%
# mean
length_missing.head()
length_missing.mean()
length.isna().mean()
# Out:
# Victims           0.002165
# Date              0.030303
# Type of attack    0.064935
# Address           0.017316
# Notes             0.164502
# Integer           0.073593
# dtype: float64

# %%
# column less than 15%
length.drop(length.columns[length.isnull().mean()>0.15],axis=1)
# Out:
#                                            Victims             Date  \
# 0                           Martino Raineri, male         17-Jan-22
# 1                          Stanley Russ, 72, male         29-May-20
# 2                 Vlastimil Vejrosta and his wife   April 30, 2020
# 3                      Timur Makhametov, 23, male         30-Dec-19
# 4                            Unknown, adult, male         12-Dec-19
# ..                                             ...              ...
# 457                          Anna Maria, 9, female      March, 1705
# 458                                      16 people             1704
# 459             Unknown girl, age unknown, female              1650
# 460                                 40+ Parisians              1439
# 461  Radegund von Wellenburg, age unknown, female    July 18, 1340
#
#     Type of attack                                            Address  Integer
# ...

# %%
# all row with missing value
length.tail(3)
length.dropna()
# Out:
#                                            Victims             Date  \
# 0                           Martino Raineri, male         17-Jan-22
# 2                 Vlastimil Vejrosta and his wife   April 30, 2020
# 3                      Timur Makhametov, 23, male         30-Dec-19
# 4                            Unknown, adult, male         12-Dec-19
# 5                      Vladislav Lomako, 56, male          8-Dec-19
# ..                                             ...              ...
# 456                   Maria Campascina, 65, female  August 28, 1705
# 457                          Anna Maria, 9, female      March, 1705
# 459             Unknown girl, age unknown, female              1650
# 460                                 40+ Parisians              1439
# 461  Radegund von Wellenburg, age unknown, female    July 18, 1340
#
#     Type of attack                                            Address  \
# 0       Unprovoked  Between Malga Seconda Posta and Forte Cherle, ...
# ...

# %%
new_length = length.fillna({
          'Date': 2002,
          'Type of attack' : 'Predatory',
          'Integer' : 2500,
          'Victims' : 'Several',
          'Address' : 'U.S.A',
          'Notes'  : 'Wolf Attack',
})
new_length
# Out:
#                                            Victims             Date  \
# 0                           Martino Raineri, male         17-Jan-22
# 1                          Stanley Russ, 72, male         29-May-20
# 2                 Vlastimil Vejrosta and his wife   April 30, 2020
# 3                      Timur Makhametov, 23, male         30-Dec-19
# 4                            Unknown, adult, male         12-Dec-19
# ..                                             ...              ...
# 457                          Anna Maria, 9, female      March, 1705
# 458                                      16 people             1704
# 459             Unknown girl, age unknown, female              1650
# 460                                 40+ Parisians              1439
# 461  Radegund von Wellenburg, age unknown, female    July 18, 1340
#
#     Type of attack                                            Address  \
# 0       Unprovoked  Between Malga Seconda Posta and Forte Cherle, ...
# ...

# %%
df_length = length.fillna(value=length['Integer'].mean())
df_length
# Out:
#                                            Victims             Date  \
# 0                           Martino Raineri, male         17-Jan-22
# 1                          Stanley Russ, 72, male         29-May-20
# 2                 Vlastimil Vejrosta and his wife   April 30, 2020
# 3                      Timur Makhametov, 23, male         30-Dec-19
# 4                            Unknown, adult, male         12-Dec-19
# ..                                             ...              ...
# 457                          Anna Maria, 9, female      March, 1705
# 458                                      16 people             1704
# 459             Unknown girl, age unknown, female              1650
# 460                                 40+ Parisians              1439
# 461  Radegund von Wellenburg, age unknown, female    July 18, 1340
#
#     Type of attack                                            Address  \
# 0       Unprovoked  Between Malga Seconda Posta and Forte Cherle, ...
# ...

# %%
df_length = length.fillna(value=length['Integer'].max())
df_length
# Out:
#                                            Victims             Date  \
# 0                           Martino Raineri, male         17-Jan-22
# 1                          Stanley Russ, 72, male         29-May-20
# 2                 Vlastimil Vejrosta and his wife   April 30, 2020
# 3                      Timur Makhametov, 23, male         30-Dec-19
# 4                            Unknown, adult, male         12-Dec-19
# ..                                             ...              ...
# 457                          Anna Maria, 9, female      March, 1705
# 458                                      16 people             1704
# 459             Unknown girl, age unknown, female              1650
# 460                                 40+ Parisians              1439
# 461  Radegund von Wellenburg, age unknown, female    July 18, 1340
#
#     Type of attack                                            Address  \
# 0       Unprovoked  Between Malga Seconda Posta and Forte Cherle, ...
# ...

# %%
df_length = length.fillna(value=length['Integer'].min())
df_length
# Out:
#                                            Victims             Date  \
# 0                           Martino Raineri, male         17-Jan-22
# 1                          Stanley Russ, 72, male         29-May-20
# 2                 Vlastimil Vejrosta and his wife   April 30, 2020
# 3                      Timur Makhametov, 23, male         30-Dec-19
# 4                            Unknown, adult, male         12-Dec-19
# ..                                             ...              ...
# 457                          Anna Maria, 9, female      March, 1705
# 458                                      16 people             1704
# 459             Unknown girl, age unknown, female              1650
# 460                                 40+ Parisians              1439
# 461  Radegund von Wellenburg, age unknown, female    July 18, 1340
#
#     Type of attack                                            Address  \
# 0       Unprovoked  Between Malga Seconda Posta and Forte Cherle, ...
# ...
